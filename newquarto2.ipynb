# %%
from google.colab import drive
from IPython.display import HTML

# %%
# !pip install quarto-cli --quiet

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !quarto render "/content/drive/MyDrive/Colab Notebooks/New_ WaterReport.ipynb"
# Out:
# pandoc
#   to: html
#   output-file: New_ WaterReport.html
#   standalone: true
#   embed-resources: true
#   self-contained: true
#   section-divs: true
#   html-math-method: mathjax
#   wrap: none
#   default-image-extension: png
#   toc: true
#
# metadata
#   document-css: false
#   link-citations: true
#   date-format: long
#   lang: en
#   title: UNICEF Global Water Access Report
#   subtitle: Analysising The Access to Safe Drinking Water
#   author:
#     - name: Maitreyi Gupta
#   theme: united
#   smooth-scroll: true
#   toc-title: Contents
#   date: '2025-04-27'
#
# Output created: New_ WaterReport.html
